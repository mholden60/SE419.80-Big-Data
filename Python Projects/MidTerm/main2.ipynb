# %%
#!/usr/bin/env python3
########################################################################
# JeffProd Simple Python Chess Program
########################################################################
# AUTHOR	: Jean-Francois GAZET
# WEB 		: http://www.jeffprod.com
# TWITTER	: @JeffProd
# MAIL		: jeffgazet@gmail.com
# LICENCE	: GNU GENERAL PUBLIC LICENSE Version 2, June 1991
########################################################################

# Import object classes
from board import *
from engine import *

b=Board()
e=Engine()

while(True):

    b.render()

    c=input('>>> ')

    if(c=='quit' or c=='exit'):
        exit(0)

    elif(c=='undomove'):
        e.undomove(b)

    elif('setboard' in c):
        e.setboard(b,c) 

    elif(c=='getboard'):
        e.getboard(b)

    elif(c=='go'):
        e.search(b)

    elif(c=='new'):
        e.newgame(b)

    elif(c=='bench'):
        e.bench(b)        

    elif('sd ' in c):
        e.setDepth(c)

    elif('perft ' in c):
        e.perft(c,b)        

    elif(c=='legalmoves'):
        e.legalmoves(b)
        
    else:
        # coup à jouer ? ex : e2e4
        e.usermove(b,c)
# Out:
# Type a key to continue...d
#
# => Commands are :
# - "new" for a new game
# - "e2e4" for example, to move a piece
# - "e7e8q" for a promote move to queen ("r" for rook, "n" for knight, "b" for bishop)
# - "legalmoves" show legal moves for side to move
# - "undomove" to cancel the last move
# - "go" asks the engine to play now
# - "setboard [fen]" to set the board as the FEN notation given
# - "getboard" to export the current FEN board position
# - "sd [x]" to set the depth search
# - "perft [x]" : test the move generator (x = search depth)
# - "quit"... to quit
#
# 8   t   c   f   d   r   f   c   t
#
# 7   p   p   p   p   p   p   p   p
#
# 6   .   .   .   .   .   .   .   .
#
# 5   .   .   .   .   .   .   .   .
#
# 4   .   .   .   .   .   .   .   .
#
# 3   .   .   .   .   .   .   .   .
#
# 2   P   P   P   P   P   P   P   P
#
# 1   T   C   F   D   R   F   C   T
#
#     a   b   c   d   e   f   g   h
# Side to move : blanc
# Castle rights : KQkq
# >>> new
#
# Type a key to continue...s
#
# => Commands are :
# - "new" for a new game
# - "e2e4" for example, to move a piece
# - "e7e8q" for a promote move to queen ("r" for rook, "n" for knight, "b" for bishop)
# - "legalmoves" show legal moves for side to move
# - "undomove" to cancel the last move
# - "go" asks the engine to play now
# - "setboard [fen]" to set the board as the FEN notation given
# - "getboard" to export the current FEN board position
# - "sd [x]" to set the depth search
# - "perft [x]" : test the move generator (x = search depth)
# - "quit"... to quit
#
# 8   t   c   f   d   r   f   c   t
#
# 7   p   p   p   p   p   p   p   p
#
# 6   .   .   .   .   .   .   .   .
#
# 5   .   .   .   .   .   .   .   .
#
# 4   .   .   .   .   .   .   .   .
#
# 3   .   .   .   .   .   .   .   .
#
# 2   P   P   P   P   P   P   P   P
#
# 1   T   C   F   D   R   F   C   T
#
#     a   b   c   d   e   f   g   h
# Side to move : blanc
# Castle rights : KQkq
# >>> a2a3
#
# Type a key to continue...
#
# => Commands are :
# - "new" for a new game
# - "e2e4" for example, to move a piece
# - "e7e8q" for a promote move to queen ("r" for rook, "n" for knight, "b" for bishop)
# - "legalmoves" show legal moves for side to move
# - "undomove" to cancel the last move
# - "go" asks the engine to play now
# - "setboard [fen]" to set the board as the FEN notation given
# - "getboard" to export the current FEN board position
# - "sd [x]" to set the depth search
# - "perft [x]" : test the move generator (x = search depth)
# - "quit"... to quit
#
# 8   t   c   f   d   r   f   c   t
#
# 7   p   p   p   p   p   p   p   p
#
# 6   .   .   .   .   .   .   .   .
#
# 5   .   .   .   .   .   .   .   .
#
# 4   .   .   .   .   .   .   .   .
#
# 3   P   .   .   .   .   .   .   .
#
# 2   .   P   P   P   P   P   P   P
#
# 1   T   C   F   D   R   F   C   T
#
#     a   b   c   d   e   f   g   h
# Side to move : noir
# Castle rights : KQkq
#
# 1.a2a3
#
#
# Type a key to continue...t1t2
#
# => Commands are :
# - "new" for a new game
# - "e2e4" for example, to move a piece
# - "e7e8q" for a promote move to queen ("r" for rook, "n" for knight, "b" for bishop)
# - "legalmoves" show legal moves for side to move
# - "undomove" to cancel the last move
# - "go" asks the engine to play now
# - "setboard [fen]" to set the board as the FEN notation given
# - "getboard" to export the current FEN board position
# - "sd [x]" to set the depth search
# - "perft [x]" : test the move generator (x = search depth)
# - "quit"... to quit
#
# 8   t   c   f   d   r   f   c   t
#
# 7   p   p   p   p   p   p   p   p
#
# 6   .   .   .   .   .   .   .   .
#
# 5   .   .   .   .   .   .   .   .
#
# 4   .   .   .   .   .   .   .   .
#
# 3   P   .   .   .   .   .   .   .
#
# 2   .   P   P   P   P   P   P   P
#
# 1   T   C   F   D   R   F   C   T
#
#     a   b   c   d   e   f   g   h
# Side to move : noir
# Castle rights : KQkq
#
# 1.a2a3
#
# >>>
# The move must be 4 or 5 letters : e2e4, b1c3, e7e8q...
#
# Type a key to continue...b1c3
#
# => Commands are :
# - "new" for a new game
# - "e2e4" for example, to move a piece
# - "e7e8q" for a promote move to queen ("r" for rook, "n" for knight, "b" for bishop)
# - "legalmoves" show legal moves for side to move
# - "undomove" to cancel the last move
# - "go" asks the engine to play now
# - "setboard [fen]" to set the board as the FEN notation given
# - "getboard" to export the current FEN board position
# - "sd [x]" to set the depth search
# - "perft [x]" : test the move generator (x = search depth)
# - "quit"... to quit
#
# 8   t   c   f   d   r   f   c   t
#
# 7   p   p   p   p   p   p   p   p
#
# 6   .   .   .   .   .   .   .   .
#
# 5   .   .   .   .   .   .   .   .
#
# 4   .   .   .   .   .   .   .   .
#
# 3   P   .   .   .   .   .   .   .
#
# 2   .   P   P   P   P   P   P   P
#
# 1   T   C   F   D   R   F   C   T
#
#     a   b   c   d   e   f   g   h
# Side to move : noir
# Castle rights : KQkq
#
# 1.a2a3
#
# >>> go
# ply	nodes	score	pv
# 1	1	0.0	b8c6
# 2	22	0.0	b8c6 a3a4
# 3	82	0.0	b8c6 a3a4 b5a4
# 4	604	0.0	b8c6 a3a4 a8b8 b2b3
#
# Type a key to continue...x
#
# => Commands are :
# - "new" for a new game
# - "e2e4" for example, to move a piece
# - "e7e8q" for a promote move to queen ("r" for rook, "n" for knight, "b" for bishop)
# - "legalmoves" show legal moves for side to move
# - "undomove" to cancel the last move
# - "go" asks the engine to play now
# - "setboard [fen]" to set the board as the FEN notation given
# - "getboard" to export the current FEN board position
# - "sd [x]" to set the depth search
# - "perft [x]" : test the move generator (x = search depth)
# - "quit"... to quit
#
# 8   t   .   f   d   r   f   c   t
#
# 7   p   p   p   p   p   p   p   p
#
# 6   .   .   c   .   .   .   .   .
#
# 5   .   .   .   .   .   .   .   .
#
# 4   .   .   .   .   .   .   .   .
#
# 3   P   .   .   .   .   .   .   .
#
# 2   .   P   P   P   P   P   P   P
#
# 1   T   C   F   D   R   F   C   T
#
#     a   b   c   d   e   f   g   h
# Side to move : blanc
# Castle rights : KQkq
#
# 1.a2a3  b8c6
#
# >>> legal moves
# The move must be 4 or 5 letters : e2e4, b1c3, e7e8q...
#
# Type a key to continue...legalmoves
#
# => Commands are :
# - "new" for a new game
# - "e2e4" for example, to move a piece
# - "e7e8q" for a promote move to queen ("r" for rook, "n" for knight, "b" for bishop)
# - "legalmoves" show legal moves for side to move
# - "undomove" to cancel the last move
# - "go" asks the engine to play now
# - "setboard [fen]" to set the board as the FEN notation given
# - "getboard" to export the current FEN board position
# - "sd [x]" to set the depth search
# - "perft [x]" : test the move generator (x = search depth)
# - "quit"... to quit
#
# 8   t   .   f   d   r   f   c   t
#
# 7   p   p   p   p   p   p   p   p
#
# 6   .   .   c   .   .   .   .   .
#
# 5   .   .   .   .   .   .   .   .
#
# 4   .   .   .   .   .   .   .   .
#
# 3   P   .   .   .   .   .   .   .
#
# 2   .   P   P   P   P   P   P   P
#
# 1   T   C   F   D   R   F   C   T
#
#     a   b   c   d   e   f   g   h
# Side to move : blanc
# Castle rights : KQkq
#
# 1.a2a3  b8c6
#
# >>> kqkq
# Incorrect move.
#
# Type a key to continue...a2a3
#
# => Commands are :
# - "new" for a new game
# - "e2e4" for example, to move a piece
# - "e7e8q" for a promote move to queen ("r" for rook, "n" for knight, "b" for bishop)
# - "legalmoves" show legal moves for side to move
# - "undomove" to cancel the last move
# - "go" asks the engine to play now
# - "setboard [fen]" to set the board as the FEN notation given
# - "getboard" to export the current FEN board position
# - "sd [x]" to set the depth search
# - "perft [x]" : test the move generator (x = search depth)
# - "quit"... to quit
#
# 8   t   .   f   d   r   f   c   t
#
# 7   p   p   p   p   p   p   p   p
#
# 6   .   .   c   .   .   .   .   .
#
# 5   .   .   .   .   .   .   .   .
#
# 4   .   .   .   .   .   .   .   .
#
# 3   P   .   .   .   .   .   .   .
#
# 2   .   P   P   P   P   P   P   P
#
# 1   T   C   F   D   R   F   C   T
#
#     a   b   c   d   e   f   g   h
# Side to move : blanc
# Castle rights : KQkq
#
# 1.a2a3  b8c6
#
# >>> go
# ply	nodes	score	pv
# 1	1	0.0	a3a4
# 2	21	0.0	a3a4 a8b8
# 3	81	0.0	a3a4 a8b8 a4a5
# 4	731	0.0	c2c3 a8b8 a3a4 b8a8
#
# Type a key to continue...go
#
# => Commands are :
# - "new" for a new game
# - "e2e4" for example, to move a piece
# - "e7e8q" for a promote move to queen ("r" for rook, "n" for knight, "b" for bishop)
# - "legalmoves" show legal moves for side to move
# - "undomove" to cancel the last move
# - "go" asks the engine to play now
# - "setboard [fen]" to set the board as the FEN notation given
# - "getboard" to export the current FEN board position
# - "sd [x]" to set the depth search
# - "perft [x]" : test the move generator (x = search depth)
# - "quit"... to quit
#
# 8   t   .   f   d   r   f   c   t
#
# 7   p   p   p   p   p   p   p   p
#
# 6   .   .   c   .   .   .   .   .
#
# 5   .   .   .   .   .   .   .   .
#
# 4   .   .   .   .   .   .   .   .
#
# 3   P   .   P   .   .   .   .   .
#
# 2   .   P   .   P   P   P   P   P
#
# 1   T   C   F   D   R   F   C   T
#
#     a   b   c   d   e   f   g   h
# Side to move : noir
# Castle rights : KQkq
#
# 1.a2a3  b8c6  2.c2c3
# >>> go
# ply	nodes	score	pv
# 1	1	0.0	a8b8
# 2	24	0.0	a8b8 a3a4
# 3	92	0.0	a8b8 a3a4 d4e2
# 4	2559	-0.1	a8b8 a3a4 a8b8 c3c4
#
# Type a key to continue...go
#
# => Commands are :
# - "new" for a new game
# - "e2e4" for example, to move a piece
# - "e7e8q" for a promote move to queen ("r" for rook, "n" for knight, "b" for bishop)
# - "legalmoves" show legal moves for side to move
# - "undomove" to cancel the last move
# - "go" asks the engine to play now
# - "setboard [fen]" to set the board as the FEN notation given
# - "getboard" to export the current FEN board position
# - "sd [x]" to set the depth search
# - "perft [x]" : test the move generator (x = search depth)
# - "quit"... to quit
#
# 8   .   t   f   d   r   f   c   t
#
# 7   p   p   p   p   p   p   p   p
#
# 6   .   .   c   .   .   .   .   .
#
# 5   .   .   .   .   .   .   .   .
#
# 4   .   .   .   .   .   .   .   .
#
# 3   P   .   P   .   .   .   .   .
#
# 2   .   P   .   P   P   P   P   P
#
# 1   T   C   F   D   R   F   C   T
#
#     a   b   c   d   e   f   g   h
# Side to move : blanc
# Castle rights : KQk
#
# 1.a2a3  b8c6  2.c2c3  a8b8
